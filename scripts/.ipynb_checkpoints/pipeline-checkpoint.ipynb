# %% [markdown]
# # Importing Libraries and Modules

# %%
# Imports 
import os
import sys
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import json
import numpy as np

# %%
# Module Imports
# Add the scripts directory to the Python path
sys.path.append(os.path.abspath("../scripts"))

# Import from script files directly (no 'scripts.' prefix)
from load_data import process_star_sample, save_processed_lightcurves
from star_catalog import stars
import importlib

import plot_utils  # the actual module
import inject_synthetic_flares  # the actual module
import lstm_flare_classifier
importlib.reload(plot_utils)
importlib.reload(inject_synthetic_flares)
importlib.reload(lstm_flare_classifier)

from plot_utils import plot_raw_lightcurves, plot_synthetic_lightcurves
from inject_synthetic_flares import inject_into_lightcurves
from lstm_flare_classifier import train_model, load_model, evaluate_model, predict_single_sequence

# %% [markdown]
# # Parameters for Pre-Processing

# %%
# -----------------------
# Parameters
# -----------------------
cadence = "short"          # 2-minute cadence
mission = "TESS"
author = "SPOC"
sector_constraint = None   # Use all sectors

output_raw_path = "../data/processed_lightcurves.pkl"
output_synthetic_path = "../data/synthetic_lightcurves.pkl"

# %% [markdown]
# # Fetching and Processing Lightcurves from MAST API

# %%
# Run Processing
print("Starting light curve processing...")

processed_lightcurves = process_star_sample(
    stars_dict=stars,
    cadence=cadence,
    mission=mission,
    author=author,
    sector_constraint=sector_constraint
)
# Out:
# Starting light curve processing...
#
# Processing M-Dwarf stars...
# TIC 117955697
# Stored Sector 57 with 0 flares.
# TIC 238302206
# Stored Sector 57 with 0 flares.
# TIC 257503361
# Stored Sector 70 with 0 flares.
# TIC 238407367
# No data found for target "TIC 238407367".
# No data found for target "TIC 238407367".
#  No data found... skipping...
# No valid data for TIC 238407367
# TIC 293257611
# Stored Sector 70 with 0 flares.
# TIC 150784513
# No data found for target "TIC 150784513".
# No data found for target "TIC 150784513".
#  No data found... skipping...
# No valid data for TIC 150784513
# TIC 29780677
# Warning: 30% (5871/19412) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# Warning: 30% (5871/19412) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# Stored Sector 39 with 1 flares.
# TIC 83806907
# Stored Sector 24 with 0 flares.
# TIC 194386500
# Stored Sector 17 with 0 flares.
# TIC 369826081
# Stored Sector 24 with 0 flares.
# TIC 405608275
# Stored Sector 57 with 0 flares.
# TIC 405186527
# Stored Sector 43 with 0 flares.
# TIC 439992889
# Stored Sector 57 with 1 flares.
# TIC 242841582
# Stored Sector 17 with 0 flares.
# TIC 369490580
# No data found for target "TIC 369490580".
# No data found for target "TIC 369490580".
#  No data found... skipping...
# No valid data for TIC 369490580
# TIC 370766645
# No data found for target "TIC 370766645".
# No data found for target "TIC 370766645".
#  No data found... skipping...
# No valid data for TIC 370766645
# TIC 270371511
# No data found for target "TIC 270371511".
# No data found for target "TIC 270371511".
#  No data found... skipping...
# No valid data for TIC 270371511
# TIC 408626802
# Stored Sector 43 with 0 flares.
# TIC 285427634
# Stored Sector 58 with 0 flares.
# TIC 372121288
# Stored Sector 58 with 1 flares.
# TIC 202932899
# Stored Sector 18 with 0 flares.
# TIC 301917244
# No data found for target "TIC 301917244".
# No data found for target "TIC 301917244".
#  No data found... skipping...
# No valid data for TIC 301917244
# TIC 436856183
# Stored Sector 58 with 0 flares.
# TIC 328181231
# Stored Sector 4 with 0 flares.
# TIC 328181231
# Stored Sector 4 with 0 flares.
# TIC 269913686
# Stored Sector 58 with 0 flares.
# TIC 426985194
# Stored Sector 71 with 0 flares.
# TIC 186717795
# Stored Sector 18 with 0 flares.
# TIC 333704067
# Stored Sector 44 with 0 flares.
# TIC 274194992
# Stored Sector 31 with 0 flares.
#
# Processing K-Dwarf stars...
# TIC 117929446
# Stored Sector 57 with 0 flares.
# TIC 118003683
# Stored Sector 57 with 0 flares.
# TIC 177707467
# Stored Sector 17 with 0 flares.
# TIC 238302760
# Stored Sector 57 with 0 flares.
# TIC 417585719
# No data found for target "TIC 417585719".
# No data found for target "TIC 417585719".
#  No data found... skipping...
# No valid data for TIC 417585719
# TIC 456502768
# Stored Sector 83 with 0 flares.
# TIC 117930174
# Stored Sector 57 with 0 flares.
# TIC 257523130
# Stored Sector 70 with 0 flares.
# TIC 346840036
# No data found for target "TIC 346840036".
# No data found for target "TIC 346840036".
#  No data found... skipping...
# No valid data for TIC 346840036
# TIC 118031332
# Stored Sector 57 with 0 flares.
# TIC 282723287
# Stored Sector 17 with 0 flares.
# TIC 293256961
# Stored Sector 42 with 0 flares.
# TIC 344630071
# Stored Sector 43 with 0 flares.
# TIC 258868174
# Stored Sector 57 with 0 flares.
# TIC 470870143
# Stored Sector 52 with 0 flares.
# TIC 258868172
# Stored Sector 57 with 0 flares.
# TIC 303205354
# Stored Sector 57 with 0 flares.
# TIC 406771828
# No data found for target "TIC 406771828".
# No data found for target "TIC 406771828".
#  No data found... skipping...
# No valid data for TIC 406771828
# TIC 397586075
# Stored Sector 43 with 0 flares.
# TIC 344630071
# Stored Sector 43 with 0 flares.
# TIC 344771096
# Stored Sector 43 with 0 flares.
# TIC 388811493
# Stored Sector 43 with 0 flares.
# TIC 435863562
# Stored Sector 17 with 0 flares.
# TIC 414809846
# Stored Sector 57 with 0 flares.
# TIC 252118059
# No data found for target "TIC 252118059".
# No data found for target "TIC 252118059".
#  No data found... skipping...
# No valid data for TIC 252118059
# TIC 252118059
#  No data found... skipping...
# No valid data for TIC 252118059
# TIC 320280898
# No data found for target "TIC 320280898".
# No data found for target "TIC 320280898".
#  No data found... skipping...
# No valid data for TIC 320280898
# TIC 302200492
# Stored Sector 43 with 0 flares.
# TIC 77353410
# Stored Sector 18 with 0 flares.
# TIC 61287258
# Stored Sector 17 with 0 flares.
#
# Processing G-Type stars...
# TIC 117929290
# Stored Sector 57 with 0 flares.
# TIC 405267612
# Stored Sector 42 with 0 flares.
# TIC 432552383
# Stored Sector 17 with 0 flares.
# TIC 258876983
# Stored Sector 57 with 0 flares.
# TIC 403024226
# Stored Sector 42 with 0 flares.
# TIC 461577810
# Stored Sector 40 with 0 flares.
# TIC 201691765
# Stored Sector 17 with 0 flares.
# TIC 405191427
# Stored Sector 43 with 0 flares.
# TIC 194461725
# Stored Sector 17 with 0 flares.
# TIC 468282175
# Stored Sector 53 with 0 flares.
# TIC 258751250
# Stored Sector 17 with 0 flares.
# TIC 258751250
# Stored Sector 17 with 0 flares.
# TIC 439996850
# Stored Sector 84 with 5 flares.
# TIC 82971688
# No data found for target "TIC 82971688".
# No data found for target "TIC 82971688".
#  No data found... skipping...
# No valid data for TIC 82971688
# TIC 468327411
# Stored Sector 25 with 0 flares.
# TIC 258770622
# Stored Sector 57 with 0 flares.
# TIC 272157589
# Stored Sector 43 with 0 flares.
# TIC 312461138
# No data found for target "TIC 312461138".
# No data found for target "TIC 312461138".
#  No data found... skipping...
# No valid data for TIC 312461138
# TIC 312461138
#  No data found... skipping...
# No valid data for TIC 312461138
# TIC 16883028
# Stored Sector 17 with 0 flares.
# TIC 16883028
# Stored Sector 17 with 0 flares.
# TIC 376981235
# Stored Sector 43 with 0 flares.
# TIC 301943748
# Stored Sector 57 with 0 flares.
# TIC 435872775
# Stored Sector 17 with 0 flares.
# TIC 53831764
# Stored Sector 17 with 0 flares.
# TIC 369090583
# No data found for target "TIC 369090583".
# No data found for target "TIC 369090583".
#  No data found... skipping...
# No valid data for TIC 369090583
# TIC 369090583
#  No data found... skipping...
# No valid data for TIC 369090583
# TIC 357528774
# Stored Sector 57 with 0 flares.
# TIC 186530056
# Stored Sector 17 with 0 flares.
# TIC 376939954
# Stored Sector 42 with 0 flares.
#
# Processing F-Type stars...
# TIC 378537940
# Stored Sector 24 with 0 flares.
# TIC 396233343
# Stored Sector 17 with 0 flares.
# TIC 396394873
# Stored Sector 17 with 0 flares.
# TIC 403021953
# Stored Sector 42 with 0 flares.
# TIC 405268431
# Stored Sector 42 with 6 flares.
# TIC 407335307
# Stored Sector 17 with 0 flares.
# TIC 418988281
# No data found for target "TIC 418988281".
# No data found for target "TIC 418988281".
#  No data found... skipping...
# No valid data for TIC 418988281
# TIC 384884605
# Stored Sector 43 with 0 flares.
# TIC 468571615
# No data found for target "TIC 468571615".
# No data found for target "TIC 468571615".
#  No data found... skipping...
# No valid data for TIC 468571615
# TIC 243225951
# Stored Sector 17 with 0 flares.
# TIC 408237293
# Stored Sector 17 with 0 flares.
# TIC 331518137
# No data found for target "TIC 331518137".
# No data found for target "TIC 331518137".
#  No data found... skipping...
# No valid data for TIC 331518137
# TIC 376907056
# Stored Sector 43 with 0 flares.
# TIC 388815746
# Stored Sector 43 with 0 flares.
# TIC 240990875
# Stored Sector 18 with 0 flares.
# TIC 332263991
# No data found for target "TIC 332263991".
# No data found for target "TIC 332263991".
#  No data found... skipping...
# No valid data for TIC 332263991
# TIC 357528236
# Stored Sector 17 with 0 flares.
# TIC 268151389
# Stored Sector 17 with 0 flares.
# TIC 344297375
# Warning: 30% (5871/19412) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# Warning: 30% (5871/19412) of the cadences will be ignored due to the quality mask (quality_bitmask=175).
# Stored Sector 3 with 0 flares.
# TIC 126999479
# Stored Sector 17 with 0 flares.
# TIC 397981427
# Stored Sector 24 with 0 flares.
# TIC 278774296
# No data found for target "TIC 278774296".
# No data found for target "TIC 278774296".
#  No data found... skipping...
# No valid data for TIC 278774296
# TIC 400498945
# No data found for target "TIC 400498945".
# No data found for target "TIC 400498945".
#  No data found... skipping...
# No valid data for TIC 400498945
# TIC 61573272
# Stored Sector 17 with 0 flares.
# TIC 400503418
# Stored Sector 58 with 0 flares.
# TIC 71852020
# Stored Sector 58 with 1 flares.
# TIC 293457962
# Stored Sector 30 with 0 flares.
# TIC 428772395
# Stored Sector 58 with 0 flares.
# TIC 285424422
# Stored Sector 18 with 0 flares.
# TIC 302620316
# Stored Sector 52 with 0 flares.

# %%
# Save Output
save_processed_lightcurves(processed_lightcurves, filepath=output_raw_path)
print("Pipeline complete.")
# Out:
# Saved light curves to ../data/processed_lightcurves.pkl
# Pipeline complete.

# %%
with open(output_raw_path, 'rb') as f:
    processed_lightcurves = pickle.load(f)

plot_raw_lightcurves(processed_lightcurves, output_dir="../data/figures/raw")
print("Plotting complete.")
# Out:
# ✅ Inside plot_raw_lightcurves function
#
# 📈 TIC 117955697: Preparing plot...
# ✅ TIC 117955697 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_117955697_Sector_57.png
#
# 📈 TIC 238302206: Preparing plot...
# ✅ TIC 238302206 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_238302206_Sector_57.png
#
# 📈 TIC 257503361: Preparing plot...
# ✅ TIC 257503361 (Sector 70): 0 flares detected.
# Saved plot to ../data/Figures/TIC_257503361_Sector_70.png
#
# 📈 TIC 293257611: Preparing plot...
# ✅ TIC 293257611 (Sector 70): 0 flares detected.
# Saved plot to ../data/Figures/TIC_293257611_Sector_70.png
#
# 📈 TIC 29780677: Preparing plot...
# ✅ TIC 29780677 (Sector 39): 2 flares detected.
# Saved plot to ../data/Figures/TIC_29780677_Sector_39.png
#
# 📈 TIC 83806907: Preparing plot...
# ✅ TIC 83806907 (Sector 24): 0 flares detected.
# Saved plot to ../data/Figures/TIC_83806907_Sector_24.png
#
# 📈 TIC 194386500: Preparing plot...
# ✅ TIC 194386500 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_194386500_Sector_17.png
#
# 📈 TIC 369826081: Preparing plot...
# ✅ TIC 369826081 (Sector 24): 0 flares detected.
# Saved plot to ../data/Figures/TIC_369826081_Sector_24.png
#
# 📈 TIC 405608275: Preparing plot...
# ✅ TIC 405608275 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_405608275_Sector_57.png
#
# 📈 TIC 405186527: Preparing plot...
# ✅ TIC 405186527 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_405186527_Sector_43.png
#
# 📈 TIC 439992889: Preparing plot...
# ✅ TIC 439992889 (Sector 57): 7 flares detected.
# Saved plot to ../data/Figures/TIC_439992889_Sector_57.png
#
# 📈 TIC 242841582: Preparing plot...
# ✅ TIC 242841582 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_242841582_Sector_17.png
#
# 📈 TIC 408626802: Preparing plot...
# ✅ TIC 408626802 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_408626802_Sector_43.png
#
# 📈 TIC 285427634: Preparing plot...
# ✅ TIC 285427634 (Sector 58): 0 flares detected.
# Saved plot to ../data/Figures/TIC_285427634_Sector_58.png
#
# 📈 TIC 372121288: Preparing plot...
# ✅ TIC 372121288 (Sector 58): 2 flares detected.
# Saved plot to ../data/Figures/TIC_372121288_Sector_58.png
#
# 📈 TIC 202932899: Preparing plot...
# ✅ TIC 202932899 (Sector 18): 0 flares detected.
# Saved plot to ../data/Figures/TIC_202932899_Sector_18.png
#
# 📈 TIC 436856183: Preparing plot...
# ✅ TIC 436856183 (Sector 58): 0 flares detected.
# Saved plot to ../data/Figures/TIC_436856183_Sector_58.png
#
# 📈 TIC 328181231: Preparing plot...
# ✅ TIC 328181231 (Sector 4): 0 flares detected.
# Saved plot to ../data/Figures/TIC_328181231_Sector_4.png
#
# 📈 TIC 269913686: Preparing plot...
# ✅ TIC 269913686 (Sector 58): 0 flares detected.
# Saved plot to ../data/Figures/TIC_269913686_Sector_58.png
#
# 📈 TIC 426985194: Preparing plot...
# ✅ TIC 426985194 (Sector 71): 0 flares detected.
# Saved plot to ../data/Figures/TIC_426985194_Sector_71.png
#
# 📈 TIC 186717795: Preparing plot...
# ✅ TIC 186717795 (Sector 18): 0 flares detected.
# Saved plot to ../data/Figures/TIC_186717795_Sector_18.png
#
# 📈 TIC 333704067: Preparing plot...
# ✅ TIC 333704067 (Sector 44): 0 flares detected.
# Saved plot to ../data/Figures/TIC_333704067_Sector_44.png
#
# 📈 TIC 274194992: Preparing plot...
# ✅ TIC 274194992 (Sector 31): 0 flares detected.
# Saved plot to ../data/Figures/TIC_274194992_Sector_31.png
#
# 📈 TIC 117929446: Preparing plot...
# ✅ TIC 117929446 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_117929446_Sector_57.png
#
# 📈 TIC 118003683: Preparing plot...
# ✅ TIC 118003683 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_118003683_Sector_57.png
#
# 📈 TIC 177707467: Preparing plot...
# ✅ TIC 177707467 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_177707467_Sector_17.png
#
# 📈 TIC 238302760: Preparing plot...
# ✅ TIC 238302760 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_238302760_Sector_57.png
#
# 📈 TIC 456502768: Preparing plot...
# ✅ TIC 456502768 (Sector 83): 0 flares detected.
# Saved plot to ../data/Figures/TIC_456502768_Sector_83.png
#
# 📈 TIC 117930174: Preparing plot...
# ✅ TIC 117930174 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_117930174_Sector_57.png
#
# 📈 TIC 257523130: Preparing plot...
# ✅ TIC 257523130 (Sector 70): 0 flares detected.
# Saved plot to ../data/Figures/TIC_257523130_Sector_70.png
#
# 📈 TIC 118031332: Preparing plot...
# ✅ TIC 118031332 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_118031332_Sector_57.png
#
# 📈 TIC 282723287: Preparing plot...
# ✅ TIC 282723287 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_282723287_Sector_17.png
#
# 📈 TIC 293256961: Preparing plot...
# ✅ TIC 293256961 (Sector 42): 0 flares detected.
# Saved plot to ../data/Figures/TIC_293256961_Sector_42.png
#
# 📈 TIC 344630071: Preparing plot...
# ✅ TIC 344630071 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_344630071_Sector_43.png
#
# 📈 TIC 258868174: Preparing plot...
# ✅ TIC 258868174 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_258868174_Sector_57.png
#
# 📈 TIC 470870143: Preparing plot...
# ✅ TIC 470870143 (Sector 52): 0 flares detected.
# Saved plot to ../data/Figures/TIC_470870143_Sector_52.png
#
# 📈 TIC 258868172: Preparing plot...
# ✅ TIC 258868172 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_258868172_Sector_57.png
#
# 📈 TIC 303205354: Preparing plot...
# ✅ TIC 303205354 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_303205354_Sector_57.png
#
# 📈 TIC 397586075: Preparing plot...
# ✅ TIC 397586075 (Sector 43): 1 flares detected.
# Saved plot to ../data/Figures/TIC_397586075_Sector_43.png
#
# 📈 TIC 344771096: Preparing plot...
# ✅ TIC 344771096 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_344771096_Sector_43.png
#
# 📈 TIC 388811493: Preparing plot...
# ✅ TIC 388811493 (Sector 43): 1 flares detected.
# Saved plot to ../data/Figures/TIC_388811493_Sector_43.png
#
# 📈 TIC 435863562: Preparing plot...
# ✅ TIC 435863562 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_435863562_Sector_17.png
#
# 📈 TIC 414809846: Preparing plot...
# ✅ TIC 414809846 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_414809846_Sector_57.png
#
# 📈 TIC 302200492: Preparing plot...
# ✅ TIC 302200492 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_302200492_Sector_43.png
#
# 📈 TIC 77353410: Preparing plot...
# ✅ TIC 77353410 (Sector 18): 1 flares detected.
# Saved plot to ../data/Figures/TIC_77353410_Sector_18.png
#
# 📈 TIC 61287258: Preparing plot...
# ✅ TIC 61287258 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_61287258_Sector_17.png
#
# 📈 TIC 117929290: Preparing plot...
# ✅ TIC 117929290 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_117929290_Sector_57.png
#
# 📈 TIC 405267612: Preparing plot...
# ✅ TIC 405267612 (Sector 42): 0 flares detected.
# Saved plot to ../data/Figures/TIC_405267612_Sector_42.png
#
# 📈 TIC 432552383: Preparing plot...
# ✅ TIC 432552383 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_432552383_Sector_17.png
#
# 📈 TIC 258876983: Preparing plot...
# ✅ TIC 258876983 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_258876983_Sector_57.png
#
# 📈 TIC 403024226: Preparing plot...
# ✅ TIC 403024226 (Sector 42): 0 flares detected.
# Saved plot to ../data/Figures/TIC_403024226_Sector_42.png
#
# 📈 TIC 461577810: Preparing plot...
# ✅ TIC 461577810 (Sector 40): 0 flares detected.
# Saved plot to ../data/Figures/TIC_461577810_Sector_40.png
#
# 📈 TIC 201691765: Preparing plot...
# ✅ TIC 201691765 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_201691765_Sector_17.png
#
# 📈 TIC 405191427: Preparing plot...
# ✅ TIC 405191427 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_405191427_Sector_43.png
#
# 📈 TIC 194461725: Preparing plot...
# ✅ TIC 194461725 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_194461725_Sector_17.png
#
# 📈 TIC 468282175: Preparing plot...
# ✅ TIC 468282175 (Sector 53): 0 flares detected.
# Saved plot to ../data/Figures/TIC_468282175_Sector_53.png
#
# 📈 TIC 258751250: Preparing plot...
# ✅ TIC 258751250 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_258751250_Sector_17.png
#
# 📈 TIC 439996850: Preparing plot...
# ✅ TIC 439996850 (Sector 84): 42 flares detected.
# Saved plot to ../data/Figures/TIC_439996850_Sector_84.png
#
# 📈 TIC 468327411: Preparing plot...
# ✅ TIC 468327411 (Sector 25): 0 flares detected.
# Saved plot to ../data/Figures/TIC_468327411_Sector_25.png
#
# 📈 TIC 258770622: Preparing plot...
# ✅ TIC 258770622 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_258770622_Sector_57.png
#
# 📈 TIC 272157589: Preparing plot...
# ✅ TIC 272157589 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_272157589_Sector_43.png
#
# 📈 TIC 16883028: Preparing plot...
# ✅ TIC 16883028 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_16883028_Sector_17.png
#
# 📈 TIC 376981235: Preparing plot...
# ✅ TIC 376981235 (Sector 43): 1 flares detected.
# Saved plot to ../data/Figures/TIC_376981235_Sector_43.png
#
# 📈 TIC 301943748: Preparing plot...
# ✅ TIC 301943748 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_301943748_Sector_57.png
#
# 📈 TIC 435872775: Preparing plot...
# ✅ TIC 435872775 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_435872775_Sector_17.png
#
# 📈 TIC 53831764: Preparing plot...
# ✅ TIC 53831764 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_53831764_Sector_17.png
#
# 📈 TIC 357528774: Preparing plot...
# ✅ TIC 357528774 (Sector 57): 0 flares detected.
# Saved plot to ../data/Figures/TIC_357528774_Sector_57.png
#
# 📈 TIC 186530056: Preparing plot...
# ✅ TIC 186530056 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_186530056_Sector_17.png
#
# 📈 TIC 376939954: Preparing plot...
# ✅ TIC 376939954 (Sector 42): 0 flares detected.
# Saved plot to ../data/Figures/TIC_376939954_Sector_42.png
#
# 📈 TIC 378537940: Preparing plot...
# ✅ TIC 378537940 (Sector 24): 1 flares detected.
# Saved plot to ../data/Figures/TIC_378537940_Sector_24.png
#
# 📈 TIC 396233343: Preparing plot...
# ✅ TIC 396233343 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_396233343_Sector_17.png
#
# 📈 TIC 396394873: Preparing plot...
# ✅ TIC 396394873 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_396394873_Sector_17.png
#
# 📈 TIC 403021953: Preparing plot...
# ✅ TIC 403021953 (Sector 42): 0 flares detected.
# Saved plot to ../data/Figures/TIC_403021953_Sector_42.png
#
# 📈 TIC 405268431: Preparing plot...
# ✅ TIC 405268431 (Sector 42): 52 flares detected.
# Saved plot to ../data/Figures/TIC_405268431_Sector_42.png
#
# 📈 TIC 407335307: Preparing plot...
# ✅ TIC 407335307 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_407335307_Sector_17.png
#
# 📈 TIC 384884605: Preparing plot...
# ✅ TIC 384884605 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_384884605_Sector_43.png
#
# 📈 TIC 243225951: Preparing plot...
# ✅ TIC 243225951 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_243225951_Sector_17.png
#
# 📈 TIC 408237293: Preparing plot...
# ✅ TIC 408237293 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_408237293_Sector_17.png
#
# 📈 TIC 376907056: Preparing plot...
# ✅ TIC 376907056 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_376907056_Sector_43.png
#
# 📈 TIC 388815746: Preparing plot...
# ✅ TIC 388815746 (Sector 43): 0 flares detected.
# Saved plot to ../data/Figures/TIC_388815746_Sector_43.png
#
# 📈 TIC 240990875: Preparing plot...
# ✅ TIC 240990875 (Sector 18): 0 flares detected.
# Saved plot to ../data/Figures/TIC_240990875_Sector_18.png
#
# 📈 TIC 357528236: Preparing plot...
# ✅ TIC 357528236 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_357528236_Sector_17.png
#
# 📈 TIC 268151389: Preparing plot...
# ✅ TIC 268151389 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_268151389_Sector_17.png
#
# 📈 TIC 344297375: Preparing plot...
# ✅ TIC 344297375 (Sector 3): 0 flares detected.
# Saved plot to ../data/Figures/TIC_344297375_Sector_3.png
#
# 📈 TIC 126999479: Preparing plot...
# ✅ TIC 126999479 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_126999479_Sector_17.png
#
# 📈 TIC 397981427: Preparing plot...
# ✅ TIC 397981427 (Sector 24): 0 flares detected.
# Saved plot to ../data/Figures/TIC_397981427_Sector_24.png
#
# 📈 TIC 61573272: Preparing plot...
# ✅ TIC 61573272 (Sector 17): 0 flares detected.
# Saved plot to ../data/Figures/TIC_61573272_Sector_17.png
#
# 📈 TIC 400503418: Preparing plot...
# ✅ TIC 400503418 (Sector 58): 0 flares detected.
# Saved plot to ../data/Figures/TIC_400503418_Sector_58.png
#
# 📈 TIC 71852020: Preparing plot...
# ✅ TIC 71852020 (Sector 58): 3 flares detected.
# Saved plot to ../data/Figures/TIC_71852020_Sector_58.png
#
# 📈 TIC 293457962: Preparing plot...
# ✅ TIC 293457962 (Sector 30): 0 flares detected.
# Saved plot to ../data/Figures/TIC_293457962_Sector_30.png
#
# 📈 TIC 428772395: Preparing plot...
# ✅ TIC 428772395 (Sector 58): 0 flares detected.
# Saved plot to ../data/Figures/TIC_428772395_Sector_58.png
#
# 📈 TIC 285424422: Preparing plot...
# ✅ TIC 285424422 (Sector 18): 0 flares detected.
# Saved plot to ../data/Figures/TIC_285424422_Sector_18.png
#
# 📈 TIC 302620316: Preparing plot...
# ✅ TIC 302620316 (Sector 52): 0 flares detected.
# Saved plot to ../data/Figures/TIC_302620316_Sector_52.png

# %% [markdown]
# # Synthetic Flare Injection

# %%
# Generate new synthetic light curves with flare injections
synthetic_lightcurves = inject_into_lightcurves(
    processed_lightcurves,
    num_flares_range=(10, 30),         # Force at least one flare per star
    inject_in_gaps=True              # Randomly inject in or around gaps
)

# Save to disk
with open(output_synthetic_path, "wb") as f:
    pickle.dump(synthetic_lightcurves, f)

print("Synthetic flare injection complete")
# Out:
# !!!!TEST!!!
# Synthetic flare injection complete

# %%
with open(output_synthetic_path, 'rb') as f:
    synthetic_lightcurves = pickle.load(f)
plot_synthetic_lightcurves(synthetic_lightcurves, "../data/figures/synthetic")

# %% [markdown]
# # LSTM Model Training and Evaluation

# %%
# Define Paths for run
run= "run1" # Change this string to test different models/hyperparameters/different processed data 


# Define Paths Based on Run

data_path = "../data/synthetic_lightcurves.pkl"  # Input dataset (most likely output_synthetic_path)

split_path = f"../models/splits_{run}.json"         # Path to save train/val/test splits
model_path = f"../models/lstm_flare_classifier_{run}.pt"  # Path to save the trained model
output_dir = f"../outputs/{run}"                    # Directory to save metrics, confusion matrix, etc.

# %%
# Train the Model (if not already trained)
if not os.path.exists(model_path):
    print("Training model from scratch...")
    model = train_model(dataset_path=data_path,
                        split_path= split_path,
                        model_path= model_path)
else:
    print("Loading pre-trained model...")
    model = load_model(model_path=model_path)
# Out:
# Training model from scratch...
# Saved splits to ../models/splits_run1.json
# Using class weights: [1.0161094665527344, 127.4413833618164, 124.88616943359375]
# Starting training for 10 epochs...
#
# Epoch 1/10
# Batch 1/150 - Loss: 1.0930
# Batch 11/150 - Loss: 1.1038
# Batch 21/150 - Loss: 1.1009
# Batch 31/150 - Loss: 1.0939
# Batch 41/150 - Loss: 1.1046
# Batch 51/150 - Loss: 1.1042
# Batch 61/150 - Loss: 1.1046
# Batch 71/150 - Loss: 1.1005
# Batch 81/150 - Loss: 1.0962
# Batch 91/150 - Loss: 1.1008
# Batch 101/150 - Loss: 1.0977
# Batch 111/150 - Loss: 1.1011
# Batch 121/150 - Loss: 1.0967
# Batch 131/150 - Loss: 1.0998
# Batch 141/150 - Loss: 1.0973
# Epoch 1 complete - Average Loss: 1.1004
#
# Validation Loss: 1.0985
# Epoch 2/10
# Batch 1/150 - Loss: 1.0982
# Batch 11/150 - Loss: 1.0971
# Batch 21/150 - Loss: 1.0987
# Batch 31/150 - Loss: 1.1001
# Batch 41/150 - Loss: 1.0979
# Batch 51/150 - Loss: 1.0995
# Batch 61/150 - Loss: 1.1000
# Batch 71/150 - Loss: 1.0994
# Batch 81/150 - Loss: 1.0991
# Batch 91/150 - Loss: 1.1012
# Batch 101/150 - Loss: 1.0947
# Batch 111/150 - Loss: 1.0992
# Batch 121/150 - Loss: 1.1002
# Batch 131/150 - Loss: 1.0957
# Batch 141/150 - Loss: 1.1001
# Epoch 2 complete - Average Loss: 1.0985
#
# Validation Loss: 1.0952
# Epoch 3/10
# Batch 1/150 - Loss: 1.0947
# Batch 11/150 - Loss: 1.0917
# Batch 21/150 - Loss: 1.1021
# Batch 31/150 - Loss: 1.1013
# Batch 41/150 - Loss: 1.1028
# Batch 51/150 - Loss: 1.0976
# Batch 61/150 - Loss: 1.0976
# Batch 71/150 - Loss: 1.0994
# Batch 81/150 - Loss: 1.0999
# Batch 91/150 - Loss: 1.0994
# Batch 101/150 - Loss: 1.0969
# Batch 111/150 - Loss: 1.0979
# Batch 121/150 - Loss: 1.0999
# Batch 131/150 - Loss: 1.0987
# Batch 141/150 - Loss: 1.0988
# Epoch 3 complete - Average Loss: 1.0984
#
# Validation Loss: 1.0948
# Epoch 4/10
# Batch 1/150 - Loss: 1.0971
# Batch 11/150 - Loss: 1.1019
# Batch 21/150 - Loss: 1.1012
# Batch 31/150 - Loss: 1.1030
# Batch 41/150 - Loss: 1.1017
# Batch 51/150 - Loss: 1.1035
# Batch 61/150 - Loss: 1.1011
# Batch 71/150 - Loss: 1.0992
# Batch 81/150 - Loss: 1.0956
# Batch 91/150 - Loss: 1.0986
# Batch 101/150 - Loss: 1.1027
# Batch 111/150 - Loss: 1.0926
# Batch 121/150 - Loss: 1.0970
# Batch 131/150 - Loss: 1.1000
# Batch 141/150 - Loss: 1.0941
# Epoch 4 complete - Average Loss: 1.0983
#
# Validation Loss: 1.0940
# Epoch 5/10
# Batch 1/150 - Loss: 1.0957
# Batch 11/150 - Loss: 1.0938
# Batch 21/150 - Loss: 1.0965
# Batch 31/150 - Loss: 1.1004
# Batch 41/150 - Loss: 1.0993
# Batch 51/150 - Loss: 1.1069
# Batch 61/150 - Loss: 1.1002
# Batch 71/150 - Loss: 1.0963
# Batch 81/150 - Loss: 1.1005
# Batch 91/150 - Loss: 1.0989
# Batch 101/150 - Loss: 1.0995
# Batch 111/150 - Loss: 1.0977
# Batch 121/150 - Loss: 1.0995
# Batch 131/150 - Loss: 1.0982
# Batch 141/150 - Loss: 1.0937
# Epoch 5 complete - Average Loss: 1.0986
#
# Validation Loss: 1.0950
# Epoch 6/10
# Batch 1/150 - Loss: 1.0954
# Batch 11/150 - Loss: 1.0997
# Batch 21/150 - Loss: 1.0918
# Batch 31/150 - Loss: 1.0804
# Batch 41/150 - Loss: 1.0988
# Batch 51/150 - Loss: 1.0991
# Batch 61/150 - Loss: 1.0971
# Batch 71/150 - Loss: 1.0988
# Batch 81/150 - Loss: 1.0876
# Batch 91/150 - Loss: 1.1002
# Batch 101/150 - Loss: 1.0965
# Batch 111/150 - Loss: 1.0985
# Batch 121/150 - Loss: 1.1014
# Batch 131/150 - Loss: 1.1024
# Batch 141/150 - Loss: 1.0941
# Epoch 6 complete - Average Loss: 1.0984
#
# Validation Loss: 1.0948
# Epoch 7/10
# Batch 1/150 - Loss: 1.0981
# Batch 11/150 - Loss: 1.0983
# Batch 21/150 - Loss: 1.0990
# Batch 31/150 - Loss: 1.0990
# Batch 41/150 - Loss: 1.0991
# Batch 51/150 - Loss: 1.0956
# Batch 61/150 - Loss: 1.1016
# Batch 71/150 - Loss: 1.1000
# Batch 81/150 - Loss: 1.0970
# Batch 91/150 - Loss: 1.0965
# Batch 101/150 - Loss: 1.0983
# Batch 111/150 - Loss: 1.1017
# Batch 121/150 - Loss: 1.1035
# Batch 131/150 - Loss: 1.1011
# Batch 141/150 - Loss: 1.1009
# Epoch 7 complete - Average Loss: 1.0984

# %%
# Evaluate the Model
evaluate_model(model,
               dataset_path=data_path,
               split_path=split_path,
               visualize=True,
               save_report=True,
               output_dir=output_dir)
# Out:
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0      0.989     1.000     0.994   1194921
#            1      0.000     0.000     0.000      6860
#            2      0.000     0.000     0.000      7019
#
#     accuracy                          0.989   1208800
#    macro avg      0.330     0.333     0.331   1208800
# weighted avg      0.977     0.989     0.983   1208800
#
# Test Accuracy: 0.9885
# Saved evaluation results to ../outputs/run1/metrics.txt
# Saved confusion matrix to ../outputs/run1/confusion_matrix.png

# %%
# Use a representative light curve (replace with actual TIC ID if needed)
times = synthetic_lightcurves[117955697]["time"]  # or your loaded time array

# Check average cadence
dt = np.diff(times)
print("Mean cadence in days:", np.mean(dt))
print("Mean cadence in minutes:", np.mean(dt) * 24 * 60)
# Out:
# Mean cadence in days: 0.0013891367859354957
# Mean cadence in minutes: 2.000356971747114

# %%
print(synthetic)
# Out:
# dict_keys([117955697, 238302206, 257503361, 293257611, 29780677, 83806907, 194386500, 369826081, 405608275, 405186527, 439992889, 242841582, 408626802, 285427634, 372121288, 202932899, 436856183, 328181231, 269913686, 426985194, 186717795, 333704067, 274194992, 117929446, 118003683, 177707467, 238302760, 456502768, 117930174, 257523130, 118031332, 282723287, 293256961, 344630071, 258868174, 470870143, 258868172, 303205354, 397586075, 344771096, 388811493, 435863562, 414809846, 302200492, 77353410, 61287258, 117929290, 405267612, 432552383, 258876983, 403024226, 461577810, 201691765, 405191427, 194461725, 468282175, 258751250, 439996850, 468327411, 258770622, 272157589, 16883028, 376981235, 301943748, 435872775, 53831764, 357528774, 186530056, 376939954, 378537940, 396233343, 396394873, 403021953, 405268431, 407335307, 384884605, 243225951, 408237293, 376907056, 388815746, 240990875, 357528236, 268151389, 344297375, 126999479, 397981427, 61573272, 400503418, 71852020, 293457962, 428772395, 285424422, 302620316])
